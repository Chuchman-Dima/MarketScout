# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/new_cars_dataset.csv")

# %%
df
# Out:
#           ID           Mark  MarkId     Model  ModelId  CategoryId  Price_USD  \
# 0   39921882         Toyota      79      RAV4      715           1       6900
# 1   40168159  Mercedes-Benz      48    AMG GT      424           1     235000
# 2   40167408           Audi       6        Q5     3222           1      25300
# 3   39547226           Audi       6        Q5     3222           1      16499
# 4   40059228           Audi       6        Q5     3222           1      15900
# 5   40098785  Mercedes-Benz      48   G-Class     3048           1      46000
# 6   40167756         Nissan      55      Juke    24932           1       9999
# 7   40167602         Nissan      55     Rogue     2228           1      23300
# 8   39761844           Audi       6        Q5     3222           1      15000
# 9   37265831            BMW       9        X5       96           1      41500
# 10  39743650            BMW       9        X5       96           1      14500
# 11  40027936            BMW       9  5 Series     2319           1      49000
# 12  39863996  Mercedes-Benz      48   E-Class      428           1      43000
# 13  37229167            BMW       9  5 Series     2319           1      31500
# 14  39130365            BMW       9        X5       96           1      24400
# 15  40092633            BMW       9  5 Series     2319           1      11900
#
#    Price_UAH Price_EUR Main_Currency  ...          Expire_Date  Is_Sold  \
# 0     308706      6003           USD  ...  2026-07-23 06:34:09    False
# 1   10511550    204345           USD  ...  2026-08-16 17:18:08    False
# 2    1131669     21999           USD  ...  2026-08-16 14:52:04    False
# 3     738000     14346           USD  ...  2026-08-15 23:24:05    False
# 4     711207     13825           USD  ...  2026-08-21 22:58:17    False
# 5    2057579     39999           USD  ...  2026-07-31 23:28:05    False
# 6     447155      8694           USD  ...  2026-08-16 16:02:10    False
# 7    1041976     20260           USD  ...  2026-08-16 15:30:08    False
# 8        USD      True          2014  ...                False    False
# 9        USD     False          2019  ...                False    False
# 10       USD     False          2009  ...                False    False
# 11       USD      True          2020  ...                False    False
# 12       USD     False          2021  ...                False    False
# 13       USD      True          2017  ...                False    False
# 14       USD     False          2018  ...                False    False
# 15       USD     False          2016  ...                False    False
#
#    From_Archive On_Moderation Chips_Count Top_Level Top_Label  Hot_Type  \
# 0         False         False           0     102.0         0       NaN
# 1         False         False           0     100.0         0       NaN
# 2         False         False           0      97.0         0       NaN
# 3         False         False           0      96.0         0       NaN
# 4         False         False           0      92.0         0       NaN
# 5         False         False           0      86.0         0       NaN
# 6         False         False           0      77.0         0       NaN
# 7         False         False           0      72.0         0       NaN
# 8             0            75           0       NaN        38       0.0
# 9             0            71           0       NaN        64       0.0
# 10            0            68           0       NaN        13       0.0
# 11            0            64           0       NaN        37       0.0
# 12            0            67           0       NaN        15       0.0
# 13            0            66           0       NaN        34       0.0
# 14            0            66           0       NaN        11       0.0
# 15            0            66           0       NaN        13       0.0
#
#    Photos_Count  Description_Length
# 0          57.0                 0.0
# 1          36.0                 0.0
# 2          50.0                 0.0
# 3          66.0                 0.0
# 4          29.0                 0.0
# 5          39.0                 0.0
# 6          42.0                 0.0
# 7          37.0                 0.0
# 8           NaN                 NaN
# 9           NaN                 NaN
# 10          NaN                 NaN
# 11          NaN                 NaN
# 12          NaN                 NaN
# 13          NaN                 NaN
# 14          NaN                 NaN
# 15          NaN                 NaN
#
# [16 rows x 45 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Mark', 'MarkId', 'Model', 'ModelId', 'CategoryId', 'Price_USD',
#        'Price_UAH', 'Price_EUR', 'Main_Currency', 'Auction_Possible', 'Year',
#        'Mileage', 'Engine', 'Fuel', 'Gearbox', 'Body', 'Color', 'Drive',
#        'Wheel', 'SeatsNumber', 'DoorsNumber', 'Custom', 'ConditionId',
#        'StatusId', 'WithVideo', 'City', 'UserId', 'Is_Dealer', 'PartnerId',
#        'Phone_Verified', 'Exchange_Possible', 'Exchange_Type', 'Add_Date',
#        'Update_Date', 'Expire_Date', 'Is_Sold', 'From_Archive',
#        'On_Moderation', 'Chips_Count', 'Top_Level', 'Top_Label', 'Hot_Type',
#        'Photos_Count', 'Description_Length'],
#       dtype='object')

# %%
df_num = df.select_dtypes(include='number')

# прибрати константні колонки
df_num = df_num.loc[:, df_num.nunique() > 1]

# заповнити NaN
df_num = df_num.fillna(df_num.median())

corr = df_num.corr()

sns.heatmap(corr, annot=True, cmap='coolwarm')
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 45 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  16 non-null     int64
#  1   Mark                16 non-null     object
#  2   MarkId              16 non-null     int64
#  3   Model               16 non-null     object
#  4   ModelId             16 non-null     int64
#  5   CategoryId          16 non-null     int64
#  6   Price_USD           16 non-null     int64
#  7   Price_UAH           16 non-null     object
#  8   Price_EUR           16 non-null     object
#  9   Main_Currency       16 non-null     object
#  10  Auction_Possible    16 non-null     object
#  11  Year                16 non-null     int64
#  12  Mileage             16 non-null     object
#  13  Engine              16 non-null     object
#  14  Fuel                8 non-null      object
#  15  Gearbox             8 non-null      object
#  16  Body                8 non-null      object
#  17  Color               0 non-null      float64
#  18  Drive               16 non-null     object
#  19  Wheel               8 non-null      float64
#  20  SeatsNumber         16 non-null     int64
#  21  DoorsNumber         16 non-null     int64
#  22  Custom              16 non-null     int64
#  23  ConditionId         16 non-null     object
#  24  StatusId            16 non-null     object
#  25  WithVideo           16 non-null     object
#  26  City                16 non-null     object
#  27  UserId              16 non-null     int64
#  28  Is_Dealer           16 non-null     bool
#  29  PartnerId           16 non-null     object
#  30  Phone_Verified      16 non-null     object
#  31  Exchange_Possible   16 non-null     object
#  32  Exchange_Type       16 non-null     object
#  33  Add_Date            16 non-null     object
#  34  Update_Date         16 non-null     object
#  35  Expire_Date         16 non-null     object
#  36  Is_Sold             16 non-null     bool
#  37  From_Archive        16 non-null     object
#  38  On_Moderation       16 non-null     object
#  39  Chips_Count         16 non-null     int64
#  40  Top_Level           8 non-null      float64
#  41  Top_Label           16 non-null     int64
#  42  Hot_Type            8 non-null      float64
#  43  Photos_Count        8 non-null      float64
#  44  Description_Length  8 non-null      float64
# dtypes: bool(2), float64(6), int64(12), object(25)
# memory usage: 5.5+ KB

# %%
df2 = pd.read_csv("../data/new_cars_dataset_2.csv")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8 entries, 0 to 7
# Data columns (total 72 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  8 non-null      int64
#  1   Mark                8 non-null      object
#  2   MarkId              8 non-null      int64
#  3   Model               8 non-null      object
#  4   ModelId             8 non-null      int64
#  5   Modification        0 non-null      float64
#  6   CategoryId          8 non-null      int64
#  7   Price_USD           8 non-null      int64
#  8   Price_UAH           8 non-null      int64
#  9   Main_Currency       8 non-null      object
#  10  Auction_Possible    8 non-null      bool
#  11  Year                8 non-null      int64
#  12  Age                 8 non-null      int64
#  13  Mileage_K           8 non-null      int64
#  14  Mileage_Per_Year    8 non-null      float64
#  15  Engine_Volume       8 non-null      float64
#  16  Fuel_Name           8 non-null      object
#  17  Fuel_Id             8 non-null      int64
#  18  Gearbox_Name        8 non-null      object
#  19  Gearbox_Id          8 non-null      int64
#  20  Body_Name           0 non-null      float64
#  21  Body_Id             8 non-null      int64
#  22  Color_Name          0 non-null      float64
#  23  Color_Id            8 non-null      int64
#  24  Drive_Name          8 non-null      object
#  25  Drive_Id            8 non-null      int64
#  26  Wheel_Name          0 non-null      float64
#  27  SeatsNumber         8 non-null      int64
#  28  DoorsNumber         8 non-null      int64
#  29  Custom              8 non-null      int64
#  30  Country_Origin_Id   8 non-null      int64
#  31  ConditionId         8 non-null      int64
#  32  StatusId            8 non-null      int64
#  33  Is_Crashed          8 non-null      bool
#  34  Damage_Description  0 non-null      float64
#  35  Has_VIN             8 non-null      bool
#  36  Is_Checked_VIN      8 non-null      bool
#  37  VIN                 8 non-null      object
#  38  Has_Plate           8 non-null      bool
#  39  Is_Checked_Plate    8 non-null      bool
#  40  State_Id            8 non-null      int64
#  41  State_Name          8 non-null      object
#  42  City_Id             8 non-null      int64
#  43  City                8 non-null      object
#  44  UserId              8 non-null      int64
#  45  Is_Dealer           8 non-null      bool
#  46  PartnerId           8 non-null      int64
#  47  Seller_Type         0 non-null      float64
#  48  Phone_Verified      8 non-null      bool
#  49  Exchange_Possible   8 non-null      bool
#  50  Exchange_Type       8 non-null      object
#  51  Add_Date            8 non-null      object
#  52  Update_Date         8 non-null      object
#  53  Expire_Date         8 non-null      object
#  54  Is_Sold             8 non-null      bool
#  55  From_Archive        8 non-null      bool
#  56  On_Moderation       8 non-null      bool
#  57  Views_Total         8 non-null      int64
#  58  Views_Today         8 non-null      int64
#  59  Bookmarks_Count     8 non-null      int64
#  60  Chips_Count         8 non-null      int64
#  61  Top_Level           8 non-null      int64
#  62  Top_Label           8 non-null      int64
#  63  Hot_Type            0 non-null      float64
#  64  Photos_Count        8 non-null      int64
#  65  With_Video          8 non-null      bool
#  66  Description_Length  8 non-null      int64
#  67  Options_Count       8 non-null      int64
#  68  Desc_Urgent         8 non-null      bool
#  69  Desc_Bargain        8 non-null      bool
#  70  Desc_First_Owner    8 non-null      bool
#  71  Desc_Ideal          8 non-null      bool
# dtypes: bool(17), float64(9), int64(33), object(13)
# memory usage: 3.7+ KB

# %%
df.columns
# Out:
# Index(['ID', 'Mark', 'MarkId', 'Model', 'ModelId', 'CategoryId', 'Price_USD',
#        'Price_UAH', 'Price_EUR', 'Main_Currency', 'Auction_Possible', 'Year',
#        'Mileage', 'Engine', 'Fuel', 'Gearbox', 'Body', 'Color', 'Drive',
#        'Wheel', 'SeatsNumber', 'DoorsNumber', 'Custom', 'ConditionId',
#        'StatusId', 'WithVideo', 'City', 'UserId', 'Is_Dealer', 'PartnerId',
#        'Phone_Verified', 'Exchange_Possible', 'Exchange_Type', 'Add_Date',
#        'Update_Date', 'Expire_Date', 'Is_Sold', 'From_Archive',
#        'On_Moderation', 'Chips_Count', 'Top_Level', 'Top_Label', 'Hot_Type',
#        'Photos_Count', 'Description_Length'],
#       dtype='object')

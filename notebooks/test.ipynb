# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df = pd.read_csv("../data/new_cars_dataset_2.csv")

# %%
df
# Out:
#           ID           Mark  MarkId     Model  ModelId  Modification  \
# 0   39921882         Toyota      79      RAV4      715           NaN
# 1   40168159  Mercedes-Benz      48    AMG GT      424           NaN
# 2   40167408           Audi       6        Q5     3222           NaN
# 3   39547226           Audi       6        Q5     3222           NaN
# 4   40059228           Audi       6        Q5     3222           NaN
# 5   40098785  Mercedes-Benz      48   G-Class     3048           NaN
# 6   40167756         Nissan      55      Juke    24932           NaN
# 7   39761844           Audi       6        Q5     3222           NaN
# 8   39547958          Haval    5456     Dargo    63299           NaN
# 9   40167602         Nissan      55     Rogue     2228           NaN
# 10  38722935            BMW       9        X5       96           NaN
# 11  37265831            BMW       9        X5       96           NaN
# 12  39561542            BMW       9  5 Series     2319           NaN
# 13  39743650            BMW       9        X5       96           NaN
# 14  40027936            BMW       9  5 Series     2319           NaN
# 15  39863996  Mercedes-Benz      48   E-Class      428           NaN
#
#     CategoryId  Price_USD  Price_UAH Main_Currency  ...  Top_Label  Hot_Type  \
# 0            1       6900     308706           USD  ...          0       NaN
# 1            1     235000   10513900           USD  ...          0       NaN
# 2            1      25300    1131922           USD  ...          0       NaN
# 3            1      16499     738165           USD  ...          0       NaN
# 4            1      15900     711366           USD  ...          0       NaN
# 5            1      46000    2058040           USD  ...          0       NaN
# 6            1       9999     447355           USD  ...          0       NaN
# 7            1      15000     671100           USD  ...          0       NaN
# 8            1      23800    1064098           USD  ...          0       NaN
# 9            1      23300    1041510           USD  ...          0       NaN
# 10           1      22700    1014690           USD  ...          0       NaN
# 11           1      41500    1855050           USD  ...          0       NaN
# 12           1      26999    1206315           USD  ...          0       NaN
# 13           1      14500     648150           USD  ...          0       NaN
# 14           1      48200    2154540           USD  ...          0       NaN
# 15           1      43000    1922100           USD  ...          0       NaN
#
#     Photos_Count  With_Video  Description_Length  Options_Count Desc_Urgent  \
# 0             57       False                   0              0       False
# 1             36       False                   0              0       False
# 2             50       False                   0              0       False
# 3             66       False                   0              0       False
# 4             29       False                   0              0       False
# 5             39       False                   0              0       False
# 6             42       False                   0              0       False
# 7             38       False                   0              0       False
# 8             94       False                   0              0       False
# 9             37       False                   0              0       False
# 10            33       False                   0              0       False
# 11            64       False                   0              0       False
# 12            72       False                   0              0       False
# 13            13       False                   0              0       False
# 14            37       False                   0              0       False
# 15            15       False                   0              0       False
#
#     Desc_Bargain Desc_First_Owner  Desc_Ideal
# 0          False            False       False
# 1          False            False       False
# 2          False            False       False
# 3          False            False       False
# 4          False            False       False
# 5          False            False       False
# 6          False            False       False
# 7          False            False       False
# 8          False            False       False
# 9          False            False       False
# 10         False            False       False
# 11         False            False       False
# 12         False            False       False
# 13         False            False       False
# 14         False            False       False
# 15         False            False       False
#
# [16 rows x 72 columns]

# %%
df.columns
# Out:
# Index(['ID', 'Mark', 'MarkId', 'Model', 'ModelId', 'Modification',
#        'CategoryId', 'Price_USD', 'Price_UAH', 'Main_Currency',
#        'Auction_Possible', 'Year', 'Age', 'Mileage_K', 'Mileage_Per_Year',
#        'Engine_Volume', 'Fuel_Name', 'Fuel_Id', 'Gearbox_Name', 'Gearbox_Id',
#        'Body_Name', 'Body_Id', 'Color_Name', 'Color_Id', 'Drive_Name',
#        'Drive_Id', 'Wheel_Name', 'SeatsNumber', 'DoorsNumber', 'Custom',
#        'Country_Origin_Id', 'ConditionId', 'StatusId', 'Is_Crashed',
#        'Damage_Description', 'Has_VIN', 'Is_Checked_VIN', 'VIN', 'Has_Plate',
#        'Is_Checked_Plate', 'State_Id', 'State_Name', 'City_Id', 'City',
#        'UserId', 'Is_Dealer', 'PartnerId', 'Seller_Type', 'Phone_Verified',
#        'Exchange_Possible', 'Exchange_Type', 'Add_Date', 'Update_Date',
#        'Expire_Date', 'Is_Sold', 'From_Archive', 'On_Moderation',
#        'Views_Total', 'Views_Today', 'Bookmarks_Count', 'Chips_Count',
#        'Top_Level', 'Top_Label', 'Hot_Type', 'Photos_Count', 'With_Video',
#        'Description_Length', 'Options_Count', 'Desc_Urgent', 'Desc_Bargain',
#        'Desc_First_Owner', 'Desc_Ideal'],
#       dtype='object')

# %%
df_num = df.select_dtypes(include='number')

# прибрати константні колонки
df_num = df_num.loc[:, df_num.nunique() > 1]

# заповнити NaN
df_num = df_num.fillna(df_num.median())

corr = df_num.corr()

plt.figure(figsize = (10,10))
sns.heatmap(corr, annot=True)
# Out:
# <Axes: >

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 72 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  16 non-null     int64
#  1   Mark                16 non-null     object
#  2   MarkId              16 non-null     int64
#  3   Model               16 non-null     object
#  4   ModelId             16 non-null     int64
#  5   Modification        0 non-null      float64
#  6   CategoryId          16 non-null     int64
#  7   Price_USD           16 non-null     int64
#  8   Price_UAH           16 non-null     int64
#  9   Main_Currency       16 non-null     object
#  10  Auction_Possible    16 non-null     bool
#  11  Year                16 non-null     int64
#  12  Age                 16 non-null     int64
#  13  Mileage_K           16 non-null     int64
#  14  Mileage_Per_Year    16 non-null     float64
#  15  Engine_Volume       16 non-null     float64
#  16  Fuel_Name           16 non-null     object
#  17  Fuel_Id             16 non-null     int64
#  18  Gearbox_Name        16 non-null     object
#  19  Gearbox_Id          16 non-null     int64
#  20  Body_Name           0 non-null      float64
#  21  Body_Id             16 non-null     int64
#  22  Color_Name          0 non-null      float64
#  23  Color_Id            16 non-null     int64
#  24  Drive_Name          16 non-null     object
#  25  Drive_Id            16 non-null     int64
#  26  Wheel_Name          0 non-null      float64
#  27  SeatsNumber         16 non-null     int64
#  28  DoorsNumber         16 non-null     int64
#  29  Custom              16 non-null     int64
#  30  Country_Origin_Id   16 non-null     int64
#  31  ConditionId         16 non-null     int64
#  32  StatusId            16 non-null     int64
#  33  Is_Crashed          16 non-null     bool
#  34  Damage_Description  0 non-null      float64
#  35  Has_VIN             16 non-null     bool
#  36  Is_Checked_VIN      16 non-null     bool
#  37  VIN                 16 non-null     object
#  38  Has_Plate           16 non-null     bool
#  39  Is_Checked_Plate    16 non-null     bool
#  40  State_Id            16 non-null     int64
#  41  State_Name          16 non-null     object
#  42  City_Id             16 non-null     int64
#  43  City                16 non-null     object
#  44  UserId              16 non-null     int64
#  45  Is_Dealer           16 non-null     bool
#  46  PartnerId           16 non-null     int64
#  47  Seller_Type         0 non-null      float64
#  48  Phone_Verified      16 non-null     bool
#  49  Exchange_Possible   16 non-null     bool
#  50  Exchange_Type       16 non-null     object
#  51  Add_Date            16 non-null     object
#  52  Update_Date         16 non-null     object
#  53  Expire_Date         16 non-null     object
#  54  Is_Sold             16 non-null     bool
#  55  From_Archive        16 non-null     bool
#  56  On_Moderation       16 non-null     bool
#  57  Views_Total         16 non-null     int64
#  58  Views_Today         16 non-null     int64
#  59  Bookmarks_Count     16 non-null     int64
#  60  Chips_Count         16 non-null     int64
#  61  Top_Level           16 non-null     int64
#  62  Top_Label           16 non-null     int64
#  63  Hot_Type            0 non-null      float64
#  64  Photos_Count        16 non-null     int64
#  65  With_Video          16 non-null     bool
#  66  Description_Length  16 non-null     int64
#  67  Options_Count       16 non-null     int64
#  68  Desc_Urgent         16 non-null     bool
#  69  Desc_Bargain        16 non-null     bool
#  70  Desc_First_Owner    16 non-null     bool
#  71  Desc_Ideal          16 non-null     bool
# dtypes: bool(17), float64(9), int64(33), object(13)
# memory usage: 7.3+ KB

# %%
df2 = pd.read_csv("../data/new_cars_dataset_2.csv")

# %%
df2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 16 entries, 0 to 15
# Data columns (total 72 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   ID                  16 non-null     int64
#  1   Mark                16 non-null     object
#  2   MarkId              16 non-null     int64
#  3   Model               16 non-null     object
#  4   ModelId             16 non-null     int64
#  5   Modification        0 non-null      float64
#  6   CategoryId          16 non-null     int64
#  7   Price_USD           16 non-null     int64
#  8   Price_UAH           16 non-null     int64
#  9   Main_Currency       16 non-null     object
#  10  Auction_Possible    16 non-null     bool
#  11  Year                16 non-null     int64
#  12  Age                 16 non-null     int64
#  13  Mileage_K           16 non-null     int64
#  14  Mileage_Per_Year    16 non-null     float64
#  15  Engine_Volume       16 non-null     float64
#  16  Fuel_Name           16 non-null     object
#  17  Fuel_Id             16 non-null     int64
#  18  Gearbox_Name        16 non-null     object
#  19  Gearbox_Id          16 non-null     int64
#  20  Body_Name           0 non-null      float64
#  21  Body_Id             16 non-null     int64
#  22  Color_Name          0 non-null      float64
#  23  Color_Id            16 non-null     int64
#  24  Drive_Name          16 non-null     object
#  25  Drive_Id            16 non-null     int64
#  26  Wheel_Name          0 non-null      float64
#  27  SeatsNumber         16 non-null     int64
#  28  DoorsNumber         16 non-null     int64
#  29  Custom              16 non-null     int64
#  30  Country_Origin_Id   16 non-null     int64
#  31  ConditionId         16 non-null     int64
#  32  StatusId            16 non-null     int64
#  33  Is_Crashed          16 non-null     bool
#  34  Damage_Description  0 non-null      float64
#  35  Has_VIN             16 non-null     bool
#  36  Is_Checked_VIN      16 non-null     bool
#  37  VIN                 16 non-null     object
#  38  Has_Plate           16 non-null     bool
#  39  Is_Checked_Plate    16 non-null     bool
#  40  State_Id            16 non-null     int64
#  41  State_Name          16 non-null     object
#  42  City_Id             16 non-null     int64
#  43  City                16 non-null     object
#  44  UserId              16 non-null     int64
#  45  Is_Dealer           16 non-null     bool
#  46  PartnerId           16 non-null     int64
#  47  Seller_Type         0 non-null      float64
#  48  Phone_Verified      16 non-null     bool
#  49  Exchange_Possible   16 non-null     bool
#  50  Exchange_Type       16 non-null     object
#  51  Add_Date            16 non-null     object
#  52  Update_Date         16 non-null     object
#  53  Expire_Date         16 non-null     object
#  54  Is_Sold             16 non-null     bool
#  55  From_Archive        16 non-null     bool
#  56  On_Moderation       16 non-null     bool
#  57  Views_Total         16 non-null     int64
#  58  Views_Today         16 non-null     int64
#  59  Bookmarks_Count     16 non-null     int64
#  60  Chips_Count         16 non-null     int64
#  61  Top_Level           16 non-null     int64
#  62  Top_Label           16 non-null     int64
#  63  Hot_Type            0 non-null      float64
#  64  Photos_Count        16 non-null     int64
#  65  With_Video          16 non-null     bool
#  66  Description_Length  16 non-null     int64
#  67  Options_Count       16 non-null     int64
#  68  Desc_Urgent         16 non-null     bool
#  69  Desc_Bargain        16 non-null     bool
#  70  Desc_First_Owner    16 non-null     bool
#  71  Desc_Ideal          16 non-null     bool
# dtypes: bool(17), float64(9), int64(33), object(13)
# memory usage: 7.3+ KB

# %%
df.columns
# Out:
# Index(['ID', 'Mark', 'MarkId', 'Model', 'ModelId', 'Modification',
#        'CategoryId', 'Price_USD', 'Price_UAH', 'Main_Currency',
#        'Auction_Possible', 'Year', 'Age', 'Mileage_K', 'Mileage_Per_Year',
#        'Engine_Volume', 'Fuel_Name', 'Fuel_Id', 'Gearbox_Name', 'Gearbox_Id',
#        'Body_Name', 'Body_Id', 'Color_Name', 'Color_Id', 'Drive_Name',
#        'Drive_Id', 'Wheel_Name', 'SeatsNumber', 'DoorsNumber', 'Custom',
#        'Country_Origin_Id', 'ConditionId', 'StatusId', 'Is_Crashed',
#        'Damage_Description', 'Has_VIN', 'Is_Checked_VIN', 'VIN', 'Has_Plate',
#        'Is_Checked_Plate', 'State_Id', 'State_Name', 'City_Id', 'City',
#        'UserId', 'Is_Dealer', 'PartnerId', 'Seller_Type', 'Phone_Verified',
#        'Exchange_Possible', 'Exchange_Type', 'Add_Date', 'Update_Date',
#        'Expire_Date', 'Is_Sold', 'From_Archive', 'On_Moderation',
#        'Views_Total', 'Views_Today', 'Bookmarks_Count', 'Chips_Count',
#        'Top_Level', 'Top_Label', 'Hot_Type', 'Photos_Count', 'With_Video',
#        'Description_Length', 'Options_Count', 'Desc_Urgent', 'Desc_Bargain',
#        'Desc_First_Owner', 'Desc_Ideal'],
#       dtype='object')
